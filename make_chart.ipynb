# %%
import pandas as pd
import sqlite3 as sql
import numpy as np 
import matplotlib.pyplot as plt

# %%
db = 'treasury_yield_curve_rates.db'
conn = sql.connect(db)

# %%
df = pd.read_sql("SELECT * FROM treasury_yield_table", conn)
df
# Out:
#     id      date one_mo  two_mo  three_mo  six_month  one_year  two_year  \
# 0    1  04/01/21   0.02    0.02      0.02       0.04      0.06      0.17
# 1    2  04/02/21   0.02    0.02      0.02       0.04      0.07      0.19
# 2    3  04/05/21   0.03    0.02      0.03       0.04      0.06      0.17
# 3    4  04/06/21   0.02    0.02      0.02       0.04      0.06      0.16
# 4    5  04/07/21   0.01    0.02      0.02       0.04      0.06      0.16
# 5    6  04/08/21   0.02    0.02      0.01       0.04      0.05      0.14
# 6    7  04/09/21   0.02    0.01      0.02       0.03      0.06      0.16
# 7    8  04/12/21   0.02    0.02      0.02       0.04      0.06      0.18
# 8    9  04/13/21   0.03    0.02      0.03       0.05      0.06      0.16
# 9   10  04/14/21   0.02    0.02      0.02       0.04      0.06      0.16
# 10  11  04/15/21   0.02    0.01      0.02       0.04      0.06      0.16
# 11  12  04/16/21   0.02    0.02      0.02       0.04      0.06      0.16
# 12  13  04/19/21   0.01    0.02      0.02       0.04      0.08      0.16
# 13  14  04/20/21   0.01    0.02      0.03       0.04      0.07      0.15
# 14  15  04/21/21   0.00    0.02      0.03       0.04      0.07      0.15
# 15  16  04/22/21   0.02    0.02      0.03       0.04      0.06      0.16
# 16  17  04/23/21   0.01    0.02      0.03       0.03      0.07      0.16
# 17  18  04/26/21   0.02    0.02      0.03       0.04      0.06      0.18
# 18  19  04/27/21   0.01    0.02      0.01       0.04      0.06      0.17
# 19  20  04/28/21   0.01    0.01      0.01       0.04      0.05      0.17
#
#     three_year  five_year  seven_year  ten_year  twenty_year  thirty_year
# 0         0.35       0.90        1.37      1.69         2.24         2.34
# 1         0.39       0.97        1.42      1.72         2.27         2.35
# 2         0.37       0.94        1.40      1.73         2.28         2.36
# 3         0.35       0.88        1.34      1.67         2.24         2.32
# 4         0.34       0.87        1.34      1.68         2.26         2.35
# 5         0.33       0.85        1.30      1.64         2.22         2.32
# 6         0.35       0.87        1.33      1.67         2.23         2.34
# 7         0.38       0.89        1.35      1.69         2.24         2.34
# 8         0.35       0.85        1.29      1.64         2.21         2.32
# 9         0.35       0.87        1.31      1.64         2.22         2.32
# 10        0.32       0.81        1.24      1.56         2.13         2.23
# 11        0.34       0.84        1.26      1.59         2.15         2.26
# 12        0.34       0.85        1.28      1.61         2.18         2.29
# 13        0.31       0.81        1.25      1.58         2.16         2.27
# 14        0.32       0.81        1.24      1.57         2.16         2.26
# 15        0.32       0.81        1.24      1.57         2.13         2.24
# 16        0.34       0.83        1.26      1.58         2.14         2.25
# 17        0.35       0.85        1.27      1.58         2.13         2.24
# 18        0.36       0.88        1.32      1.63         2.18         2.29
# 19        0.35       0.86        1.31      1.63         2.19         2.29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           16 non-null     int64
#  1   date         16 non-null     object
#  2   one_mo       16 non-null     object
#  3   two_mo       16 non-null     float64
#  4   three_mo     16 non-null     float64
#  5   six_month    16 non-null     float64
#  6   one_year     16 non-null     float64
#  7   two_year     16 non-null     float64
#  8   three_year   16 non-null     float64
#  9   five_year    16 non-null     float64
#  10  seven_year   16 non-null     float64
#  11  ten_year     16 non-null     float64
#  12  twenty_year  16 non-null     float64
#  13  thirty_year  16 non-null     float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
df.iloc[19][2:]
# Out:
# one_mo             0.01
# two_mo         0.010000
# three_mo       0.010000
# six_month      0.040000
# one_year       0.050000
# two_year       0.170000
# three_year     0.350000
# five_year      0.860000
# seven_year     1.310000
# ten_year       1.630000
# twenty_year    2.190000
# thirty_year    2.290000
# Name: 19, dtype: object

# %%
x = df.columns[2:]
y = list(df.iloc[19][2:])
fig, ax = plt.subplots(figsize=(20,5))
ax.plot(x,y)
labels = ax.get_xticklabels()
ax.set( xlabel = 'Maturity', ylabel= 'curve rates', title = 'some title')
plt.show()

# %%
x = df['date']
y1 = df['one_mo']
y2=df['two_mo']
y3 = df['three_mo']
plt.plot(x, y1, label = "one_mo")
plt.plot(x,y2, label = "two_mo")
plt.plot(x,y3, label = "three_mo")
plt.legend()
plt.show()

# %%
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

def make_chart(data, filename):
    print("generating matplotlib chart")
    plt.plot(data)
#     plt.savefig(f'charts/{filename}.png')
    print("completed")
    
def main():
    dt_now = dt.datetime.now()
    dt_fmt = dt_now.strftime("%m-%d-%y-%H%M%S")
    make_chart(np.arange(10), f'test-{dt_fmt}')
    
main()
# Out:
# generating matplotlib chart
# completed

# %%
conn.close()
